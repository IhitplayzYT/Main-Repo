# %%
import numpy as np
import pandas as pd
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Ridge,Lasso,ElasticNet,RidgeCV
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.pipeline import Pipeline

# %%
scaler = StandardScaler()
model = ElasticNet(alpha=0.01,l1_ratio=0.6)

# %%
df = datasets.load_diabetes()
x,y = pd.DataFrame(data=df.data,columns=df.feature_names),df.target
X,X_T,Y,Y_T = train_test_split(x_s,y,random_state=42,test_size=0.2)
X = scaler.fit_transform(X)
X_T = scaler.transform(X_T)

# %%
model.fit(X,Y)
l = model.predict(X_T)
print("MSE:", mean_squared_error(Y_T, l))
print("R2 :", r2_score(Y_T, l))
# Out:
# MSE: 2889.3001974261024
# R2 : 0.4546588443347134
