# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_wine

# %%
df = load_wine()
x,y,x_lab,y_lab = df.data,df.target,df.feature_names,df.target_names
data = pd.DataFrame(data=x,columns=x_lab)
data["target"] = y

X,X_T,Y,Y_T = train_test_split(x,y,test_size=0.2,random_state=42)
Y = Y.reshape(-1,1)
Y_T = Y_T.reshape(-1,1)
data["target"].unique()
mu = X.mean(axis=0)
sig = X.std(axis=0)
X = (X - mu) / sig
X_T = (X_T - mu) / sig
X = np.c_[np.ones((X.shape[0],1)),X]
X_T = np.c_[np.ones((X_T.shape[0],1)),X_T]
# Out:
# (142, 14) (36, 14) (142, 1) (36, 1)

# %%
def softmax(x):
    ex = np.exp(x)
    return ex / np.sum(ex ** 2)

def one_hot(y):

# %%
M = np.random.randn(X.shape[1],1)
LR,ALPHA,EPOCH = 0.01,0.1,10000

for i in range(EPOCH):
    prob = softmax(X @ M)
    grad = Y *
